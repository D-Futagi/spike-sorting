# %%
import modules
import matplotlib.pyplot as plt
import markdown
import numpy as np

# %% [markdown]
# # Step 0. Generate an instance

# %%
res = modules.Modules()

# %% [markdown]
# # Step 1. Load and filter data
# DIFFICULT01-NOISE02 is used.

# %%
res.load_data("quiroga2004-difficult-1/C_Difficult1_noise02_X.h5")
res.filtering()

# %%
res.plot_step1()

# %% [markdown]
# # Step 2. Detect spike waveforms and divide them into subsets

# %%
res.spike_detection(f_std=3.5)
res.dataset_division()

# %%
res.plot_step2()

# %% [markdown]
# # Step 3. Extract features from single-peak waveforms

# %%
res.feature_extraction(8)

# %%
res.plot_step3()

# %% [markdown]
# # Step 4. Classify single-peak waveforms and reconstruct template waveforms

# %%
res.spw_clustering(18)
res.template_reconstruction(fs=0.05)

# %%
res.plot_step4()

# %% [markdown]
# # Step 5. Classify multi-peak waveforms by template matching

# %%
res.template_matching()
# Out:
# 100%|██████████| 284/284 [07:23<00:00,  1.56s/it]

# %%
res.mpw_label_assignment(10)

# %%
res.plot_step5()

# %% [markdown]
# # Step 6. Align data and display spike-sorting result

# %%
res.data_alignment()

# %%
res.plot_step6()
